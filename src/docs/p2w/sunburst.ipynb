# %% [markdown]
# # Sunburst Chart
#
# Runnable example from the accompanying README.

# %%
import pandas as pd
import plotly.express as px

# Define a hierarchy from region to category to product.
data = pd.DataFrame(
    {
        "region": ["North", "North", "South", "South"],
        "category": ["Home", "Tech", "Home", "Tech"],
        "product": ["Chair", "Headphones", "Lamp", "Keyboard"],
        "sales": [42, 61, 35, 54],
    }
)

# Draw one ring per hierarchy level; angular size represents sales.
fig = px.sunburst(
    data,
    path=["region", "category", "product"],
    values="sales",
    color="sales",
    color_continuous_scale="Blues",
    title="Sales Hierarchy by Region and Product",
)

# Save and display the interactive chart.
fig.write_html("sunburst.html", include_plotlyjs=True)
fig.show()
